# %%
import mne
from mne.time_frequency import psd_welch, psd_multitaper
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
from matplotlib.backends.backend_pdf import PdfPages

# %%
data_jointLZC_paradox = pd.read_csv("RESULTS/complexity/Joint_complexity_paradox.txt", sep = ",")
p_id_jointLZC_paradox = data_jointLZC.iloc[np.where(data_jointLZC['ID']==p_id)]

data_jointLZC = pd.read_csv("RESULTS/complexity/Joint_complexity.txt", sep = ",")
p_id_jointLZC = data_jointLZC.iloc[np.where(data_jointLZC['ID']==p_id)]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/jt/1njpx4d93pn5y3nd0p7l5hwr0000gn/T/ipykernel_49328/2006154103.py in <module>
# ----> 1 data_jointLZC_paradox = pd.read_csv("RESULTS/complexity/Joint_complexity_paradox.txt", sep = ",")
#       2 p_id_jointLZC_paradox = data_jointLZC.iloc[np.where(data_jointLZC['ID']==p_id)]
#       3
#       4 data_jointLZC = pd.read_csv("RESULTS/complexity/Joint_complexity.txt", sep = ",")
#       5 p_id_jointLZC = data_jointLZC.iloc[np.where(data_jointLZC['ID']==p_id)]
#
# ~/miniconda3/envs/oof_env/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# # Corealtion alpha Hub and Alpha power

# %%
d = {'Power': diff_psds_apha, 'Degree': diff_degree_alpha}
df_alpha = pd.DataFrame(data=d)

# %%
# calculate Pearson's correlation
corr, p = pearsonr(df_alpha['Power'], df_alpha['Degree'])
pear_r = '%.2f' % corr
pear_p = '%.2f' % p

print('Pearsons correlation: ' + pear_r)
print('P-value: ' + pear_p)
# Out:
# Pearsons correlation: 0.08
# P-value: 0.43

# %%
sns.set(style='white', font_scale=1.2)
g = sns.JointGrid(data=df_alpha, x='Power', y='Degree', height=5)
g = g.plot_joint(sns.regplot, color="xkcd:muted blue")
g = g.plot_marginals(sns.distplot, kde=False, bins=12, color="xkcd:bluey grey")
g.ax_joint.text(-1, -4, f'r = -0.08, \np = .43', fontstyle='italic')
plt.tight_layout()
g.set_axis_labels('\u0394 Power', '\u0394 Node Degree')
# Out:
# /Users/charlotte/miniconda3/envs/oof_env/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize = (7,10))
ax = plt.subplot(111)

ax.plot([0.5, 1], [p_id_jointLZC['Joint_norm_LZC_Base'], p_id_jointLZC['Joint_norm_LZC_Anes'] ],
        'black', linewidth=3, marker = 'o')

ax.plot([0.5, 1], [p_id_concLZC['conc_norm_LZC_Base'], p_id_concLZC['conc_norm_LZC_Anes'] ],
        'black', linewidth=3, marker = 'o', linestyle='--')

ax.plot([0.5, 1], [p_id_univLZC['univ_norm_LZC_Base'], p_id_univLZC['univ_norm_LZC_Anes'] ],
        'black', linewidth=3, marker = 'o', linestyle=':')

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


ax.tick_params(axis='both', which='major', labelsize=25)
plt.xticks([0.3, 0.5, 1], ['','Baseline', 'Anesthesia'], fontsize = 25)
plt.ylabel('LZC', fontsize = 25)
plt.ylim(0.4,0.9)
plt.legend(['Joint LZC','Concatenated LZC','Univariate LZC'],prop={'size': 20},loc='lower right')
